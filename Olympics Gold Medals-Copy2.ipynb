# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
df=pd.read_csv('/Users/shajith/Downloads/Ex_Files_Pandas_EssT 2/ExerciseFiles/data/olympics.csv',skiprows=4)
df
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
mf=df.value_counts('Sport')
mf
# Out:
# Sport
# Aquatics             3828
# Athletics            3448
# Rowing               2523
# Gymnastics           2214
# Fencing              1547
# Football             1387
# Hockey               1325
# Wrestling            1140
# Shooting             1105
# Sailing              1061
# Cycling              1025
# Canoe / Kayak        1002
# Basketball            940
# Volleyball            910
# Equestrian            894
# Handball              886
# Boxing                842
# Weightlifting         548
# Judo                  435
# Baseball              335
# Archery               305
# Tennis                272
# Rugby                 192
# Softball              180
# Modern Pentathlon     174
# Badminton             120
# Table Tennis          120
# Tug of War             94
# Taekwondo              80
# Polo                   66
# Lacrosse               59
# Golf                   30
# Ice Hockey             27
# Skating                27
# Cricket                24
# ...

# %%
df
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
mf=df[(df.Edition == 2008) & (df.Event=='100m')]
mf
# Out:
#           City  Edition      Sport Discipline             Athlete  NOC Gender  \
# 27551  Beijing     2008  Athletics  Athletics         DIX, Walter  USA    Men
# 27552  Beijing     2008  Athletics  Athletics         BOLT, Usain  JAM    Men
# 27553  Beijing     2008  Athletics  Athletics   THOMPSON, Richard  TRI    Men
# 27554  Beijing     2008  Athletics  Athletics  FRASER, Shelly-ann  JAM  Women
# 27555  Beijing     2008  Athletics  Athletics    SIMPSON, Sherone  JAM  Women
# 27556  Beijing     2008  Athletics  Athletics     STEWART, Kerron  JAM  Women
#
#       Event Event_gender   Medal
# 27551  100m            M  Bronze
# 27552  100m            M    Gold
# 27553  100m            M  Silver
# 27554  100m            W    Gold
# 27555  100m            W  Silver
# 27556  100m            W  Silver

# %%
g=mf.groupby(['NOC','Sport','Event','Gender']).size()
g
# Out:
# NOC  Sport      Event  Gender
# JAM  Athletics  100m   Men       1
#                        Women     3
# TRI  Athletics  100m   Men       1
# USA  Athletics  100m   Men       1
# dtype: int64

# %%
g.unstack(['NOC','Event'])
# Out:
# NOC               JAM  TRI  USA
# Event            100m 100m 100m
# Sport     Gender
# Athletics Men     1.0  1.0  1.0
#           Women   3.0  NaN  NaN

# %%
USA=df[(df.NOC == 'USA') & (df.Medal == 'Gold')]
USA
# Out:
#           City  Edition       Sport       Discipline           Athlete  NOC  \
# 13      Athens     1896   Athletics        Athletics     BURKE, Thomas  USA
# 15      Athens     1896   Athletics        Athletics    CURTIS, Thomas  USA
# 21      Athens     1896   Athletics        Athletics     BURKE, Thomas  USA
# 27      Athens     1896   Athletics        Athletics   GARRETT, Robert  USA
# 29      Athens     1896   Athletics        Athletics     CLARK, Ellery  USA
# ...        ...      ...         ...              ...               ...  ...
# 29048  Beijing     2008  Volleyball       Volleyball      ROONEY, Sean  USA
# 29049  Beijing     2008  Volleyball       Volleyball     SALMON, Riley  USA
# 29050  Beijing     2008  Volleyball       Volleyball  STANLEY, Clayton  USA
# 29051  Beijing     2008  Volleyball       Volleyball  TOUZINSKY, Scott  USA
# 29151  Beijing     2008   Wrestling  Wrestling Free.     CEJUDO, Henry  USA
#
#       Gender         Event Event_gender Medal
# ...

# %%
USA.groupby(['Edition','Gender']).size().unstack('Gender',fill_value=0)
# Out:
# Gender   Men  Women
# Edition
# 1896      11      0
# 1900      26      1
# 1904     140      6
# 1908      34      0
# 1912      45      0
# 1920     103      7
# 1924      95     15
# 1928      34      9
# 1932      61     17
# 1936      44      7
# 1948      75      8
# 1952      72      7
# 1956      57      4
# 1960      51     17
# 1964      63     15
# 1968      59     24
# 1972      37     16
# 1976      56      7
# 1984     106     62
# 1988      49     28
# 1992      57     32
# 1996      59    101
# 2000      68     62
# 2004      51     65
# 2008      67     58

# %%
df
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
high=df.groupby(['Athlete','Medal']).size().unstack('Medal',fill_value=0).sort_values(['Gold','Silver','Bronze'],ascending=False)[['Gold','Silver','Bronze']].head(5)
high
# Out:
# Medal             Gold  Silver  Bronze
# Athlete
# PHELPS, Michael     14       0       2
# LATYNINA, Larisa     9       5       4
# NURMI, Paavo         9       3       0
# SPITZ, Mark          9       1       1
# LEWIS, Carl          9       1       0

# %%
high.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Athlete'>
